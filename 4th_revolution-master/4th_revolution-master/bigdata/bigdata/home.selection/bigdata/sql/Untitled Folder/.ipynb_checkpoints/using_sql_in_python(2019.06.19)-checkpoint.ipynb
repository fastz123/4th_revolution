# %%
import pandas as pd
import MySQLdb

# %%
connection = MySQLdb.connect(
'localhost',
    'root',
    '1234',
    'mytestdb',
    charset='utf8'
)

# %%
connection
# Out:
# <_mysql.connection open to 'localhost' at 00000207873B5348>

# %%
cursor=connection.cursor()

# %%
sql = '''
create table 
'''

# %%
sql = '''
select* from mytable;
'''

# %%
cursor.fetchall()

# %%
sql='''
insert into mytable(email,phone,address,deposit,rent)
values(
'multicampus@gamil.com',
'010-555-5555',
'서울시 강남구 역삼동',
5000,
10
);
'''

# %%
cursor.execute(sql)

# %%
sql = '''
select * from mytable;
'''

# %%
pd.read_sql(sql,connection)

# %%
db =MySQLdb.connect(
'localhost',
    'root',
    '1234',
    'sakila',
    charset='utf8'
)

# %%
df = pd.read_sql('show tables;',db)

# %%
df.head()
# Out:
#   Tables_in_sakila
# 0            actor
# 1       actor_info
# 2          address
# 3         category
# 4             city

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 1 columns):
# Tables_in_sakila    23 non-null object
# dtypes: object(1)
# memory usage: 264.0+ bytes

# %%
def save_csv(tbl_name):
    table_df=pd.read_sql('select * from {};'.format(tbl_name),db)
    table_df.to_scv('./data/{}.csv'.format(tbl_name))

# %%
df['Tables_in_sakila']
# Out:
# 0                          actor
# 1                     actor_info
# 2                        address
# 3                       category
# 4                           city
# 5                        country
# 6                       customer
# 7                  customer_list
# 8                           film
# 9                     film_actor
# 10                 film_category
# 11                     film_list
# 12                     film_text
# 13                     inventory
# 14                      language
# 15    nicer_but_slower_film_list
# 16                       payment
# 17                        rental
# 18        sales_by_film_category
# 19                sales_by_store
# 20                         staff
# 21                    staff_list
# 22                         store
# Name: Tables_in_sakila, dtype: object

# %%
df['Tables_in_sakila'].apply(save_csv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-5cbc05126074> in <module>
# ----> 1 df['Tables_in_sakila'].apply(save_csv)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-70-047c306b9299> in save_csv(tbl_name)
#       1 def save_csv(tbl_name):
#       2     table_df=pd.read_sql('select * from {};'.format(tbl_name),db)
# ----> 3     table_df.to_scv('./data/{}.csv'.format(tbl_name))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
# ...

# %%
db = MySQLdb.connect(
'localhost',
    'root',
    '1234',
    'world',
    charset='utf8'
)

# %%
df = pd.read_sql('show tables;',db)

# %%
df.head()
# Out:
#    Tables_in_world
# 0             city
# 1          country
# 2  countrylanguage

# %%
tables_df=pd.read_sql('select * from city;',db)

# %%
def save_csv(tbl_name):
    tables_df=pd.read_sql('select * from {}'.format(tbl_name),db)
    tables_df.to_csv('./data/{}.csv'.format(tbl_name))

# %%
df['Tables_in_world'].apply(save_csv)
# Out:
# 0    None
# 1    None
# 2    None
# Name: Tables_in_world, dtype: object

# %%
#name, population, continent 만을 봅아서 country_df로 출력
#pandas 와 sql로 각각 실행
#컬럼명 '이름','인구수','대륙'

# %%
data = pd.read_csv('./data/country.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Code         Name      Continent                     Region  \
# 0           0  ABW        Aruba  North America                  Caribbean
# 1           1  AFG  Afghanistan           Asia  Southern and Central Asia
# 2           2  AGO       Angola         Africa             Central Africa
# 3           3  AIA     Anguilla  North America                  Caribbean
# 4           4  ALB      Albania         Europe            Southern Europe
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        193.0        NaN      103000            78.4   828.0   793.0
# 1     652090.0     1919.0    22720000            45.9  5976.0     NaN
# 2    1246700.0     1975.0    12878000            38.3  6648.0  7984.0
# 3         96.0        NaN        8000            76.1    63.2     NaN
# 4      28748.0     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# ...

# %%
country_df= data[['Name','Population','Continent']]

# %%
country_df
# Out:
#                                      Name  Population      Continent
# 0                                   Aruba      103000  North America
# 1                             Afghanistan    22720000           Asia
# 2                                  Angola    12878000         Africa
# 3                                Anguilla        8000  North America
# 4                                 Albania     3401200         Europe
# 5                                 Andorra       78000         Europe
# 6                    Netherlands Antilles      217000  North America
# 7                    United Arab Emirates     2441000           Asia
# 8                               Argentina    37032000  South America
# 9                                 Armenia     3520000           Asia
# 10                         American Samoa       68000        Oceania
# 11                             Antarctica           0     Antarctica
# 12            French Southern territories           0     Antarctica
# ...

# %%
country_df.columns = ['국가명','인구수','대륙']

# %%
country_df.rename = (column=['Name':'국가명','Population':'인구수','Region':'대륙'])

# %%
country_df.head()
# Out:
#            국가명       인구수             대륙
# 0        Aruba    103000  North America
# 1  Afghanistan  22720000           Asia
# 2       Angola  12878000         Africa
# 3     Anguilla      8000  North America
# 4      Albania   3401200         Europe
