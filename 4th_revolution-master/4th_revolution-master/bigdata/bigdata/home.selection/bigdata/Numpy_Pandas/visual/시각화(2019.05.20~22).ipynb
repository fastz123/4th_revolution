# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize']=(5,2)

x = range(100)
y = [value**2 for value in x]

plt.plot(x,y)
plt.savefig('test.png')

# %%
X_1 = range(100)
Y_1 = [np.cos(value) for value in X_1]
X_2 = range(100)
Y_2 = [np.sin(value) for value in X_2]
plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.rcParams["figure.figsize"] = (5,2)
plt.show()

# %%
fig = plt.figure() # figure
fig.set_size_inches(10,5) #
ax_1 = fig.add_subplot(1,2,1) # plot
ax_2 = fig.add_subplot(1,2,2) # plot
ax_1.plot(X_1, Y_1, c="b") # plot
ax_2.plot(X_2, Y_2, c="g") # plot
plt.show() # show & flu

# %%
X_1 = range(100)
Y_1 = [value for value in X_1]

X_2 = range(100)
Y_2 = [value+50 for value in X_2]

plt.plot(X_1,Y_1,c='b')
plt.plot(X_2,Y_2,c='y')

# %%
plt.plot(X_1,Y_1,c='b',linestyle='dashed',label='line_1')
plt.plot(X_2,Y_2,c='g',ls='dotted',label='line_2')
plt.title('$y = {ax+b}$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')
plt.text(50,70,"Line_1")
plt.annotate('line_2',xy=(50,100),xytext=(30,110),arrowprops=dict(facecolor='black',shrink=0.1))
plt.legend(shadow=True,fancybox=False,loc='lower right')
plt.show()

# %%
data_1 = np.random.rand(512,2)
data_2 = np.random.rand(512,2)

# %%
plt.scatter(data_1[:,0],data_1[:,1],c='b',marker='x')
plt.scatter(data_2[:,0],data_2[:,1],c='r',marker='^')
plt.show()

# %%
data = [[5., 25., 50., 20.],
[4., 23., 51., 17],
[6., 22., 52., 19]]
X = np.arange(0,8,2)

# %%
plt.bar(X+0.00,data[0],color='b',width=0.50)
plt.bar(X+0.50,data[1],color='r',width=0.5)
plt.bar(X+1,data[2],color='g',width=0.5)
plt.xticks(X+0.5,('A','B','C','D'))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
[4., 23., 51., 17],
[6., 22., 52., 19]])
color_list = ['b', 'g', 'r']
data_label = ["A","B","C"]

# %%
data = np.array([[5., 5., 5., 5.],
[4., 23., 51., 17],
[6., 22., 52., 19]])

# %%
for i in range(3):
    plt.bar(X,data[i],bottom=np.sum(data[:i],axis=0),color=color_list[i],label=data_label[i])

# %%
A = [5., 30., 45., 22.]
B = [5, 25, 50, 20]
X = range(4)

# %%
plt.bar(X,A,color='b')
plt.bar(X,B,color='r',bottom=60)
plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
X = np.arange(4)

# %%
plt.barh(X,women_pop,color='r')
plt.barh(X,-men_pop,color='b')
plt.show()

# %%
X = np.random.randn(1000)
plt.hist(X,bins=100)
plt.show()

# %%
data = np.random.randn(100,5)
# print(data)
plt.boxplot(data)
plt.show()

# %% [markdown]
# ## Pandas(DataFrame)

# %%
import pandas as pd
import numpy as np
data_url = './housing.data' #Data URL
df_data = pd.read_csv(data_url, sep='\s+', header = None) #csv , separate , Column
df_data.columns = [
'CRIM','ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',\
'PTRATIO' ,'B', 'LSTAT', 'MEDV']
# Column Header
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
fig = plt.figure()
ax=[]
for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))
ax[0].scatter(df_data['CRIM'],df_data['MEDV'])
ax[1].scatter(df_data['PTRATIO'],df_data['MEDV'])
ax[2].scatter(df_data['AGE'],df_data['MEDV'])
ax[3].scatter(df_data['NOX'],df_data['MEDV'])
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(10.0,10.0, forward=True)
ax=[]
for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))
columns = ['CRIM','PTRATIO','AGE','NOX']
colors = ['b','g','c','r']
for i in range(4):
    ax[i].scatter(df_data[columns[i]],df_data['MEDV'],color=colors[i],label=columns[i])
    ax[i].legend()
    ax[i].set_title(columns[i])
plt.subplots_adjust(wspace=0,hspace=0)
plt.show()

# %%
df_data.plot()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(10,5)
ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)
ax_1.plot(df_data['MEDV'])
ax_2.hist(df_data['MEDV'],bins=50)
ax_1.set_title('HOUSE Price MEDV')
ax_2.set_title('HOUSE Price MEDV')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
scale_data = std_scaler.fit_transform(df_data)
scale_data
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-0.41978194,  0.28482986, -1.2879095 , ...,  0.44105193,
#         -1.0755623 ,  0.15968566],
#        [-0.41733926, -0.48772236, -0.59338101, ...,  0.44105193,
#         -0.49243937, -0.10152429],
#        [-0.41734159, -0.48772236, -0.59338101, ...,  0.39642699,
#         -1.2087274 ,  1.32424667],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  0.44105193,
#         -0.98304761,  0.14880191],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  0.4032249 ,
#         -0.86530163, -0.0579893 ],
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.boxplot(scale_data, labels=df_data.columns)
fig.set_size_inches(10, 5)
plt.show()

# %%
pd.scatter_matrix(df_data, diagonal="kde", alpha=1, figsize=(15, 15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-8be28f21718b> in <module>
# ----> 1 pd.scatter_matrix(df_data, diagonal="kde", alpha=1, figsize=(15, 15))
#       2 plt.show()
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
corr_data = np.corrcoef(scale_data.T[:5])
corr_data
# Out:
# array([[ 1.        , -0.20046922,  0.40658341, -0.05589158,  0.42097171],
#        [-0.20046922,  1.        , -0.53382819, -0.04269672, -0.51660371],
#        [ 0.40658341, -0.53382819,  1.        ,  0.06293803,  0.76365145],
#        [-0.05589158, -0.04269672,  0.06293803,  1.        ,  0.09120281],
#        [ 0.42097171, -0.51660371,  0.76365145,  0.09120281,  1.        ]])

# %%
corr_data.shape
# Out:
# (5, 5)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr_data, vmin=-1, vmax=1, interpolation='nearest')
fig.colorbar(cax)
fig.set_size_inches(10,10)
ticks= np.arange(0,5,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
np.random.seed(0)

# %%
x = np.random.randn(100)

# %%
sns.rugplot(x)

# %%
sns.kdeplot(x)

# %%
sns.distplot(x,rug=True)

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.residplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',col='smoker',data=tips)

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips)

# %%
titanic = sns.load_dataset('titanic')
sns.countplot(x='class',hue='who',data=titanic)

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips)

# %%
sns.pointplot(x='day',y='total_bill',hue='smoker',data=tips,dodge=True)

# %%
sns.violinplot(x='day',y='total_bill',hue='smoker',data=tips,plaette='muted')

# %%
: sns.violinplot(x="day", y="total_bill", hue="sex",data=tips, palette="Set2", split=True,scale="count", inner="quartile");
# Out:
#   File "<ipython-input-115-1df4c16f1cd5>", line 1
#     : sns.violinplot(x="day", y="total_bill", hue="sex",data=tips, palette="Set2", split=True,scale="count", inner="quartile");
#     ^
# SyntaxError: invalid syntax

# %%
sns.stripplot(x="day", y="total_bill", hue="smoker",
data=tips, jitter=True,
palette="Set2", split=True);
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='tip',y='day',data=tips,whis=np.inf)
sns.stripplot(x='tip',y='day',data=tips,jitter=True,color='.3')

# %%
sns.swarmplot(x='day',y='total_bill',hue = 'sex',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,inner=None)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black',edgecolor='grey')

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot('month','year','passengers')
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(flights, annot=True, fmt="d")
