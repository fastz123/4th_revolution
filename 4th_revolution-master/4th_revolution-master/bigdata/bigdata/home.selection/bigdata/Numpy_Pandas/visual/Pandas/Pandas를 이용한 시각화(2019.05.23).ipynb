# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (15,5)
plt.rcParams['font.size'] = 14

# %%
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drinks = pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
drinks.describe()
# Out:
#              beer      spirit        wine      liters
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country      193 non-null object
# beer         193 non-null int64
# spirit       193 non-null int64
# wine         193 non-null int64
# liters       193 non-null float64
# continent    193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks1 = drinks.copy()
drinks1.set_index(drinks['country'],inplace=True)
del drinks1['country']
del drinks1.index.name
drinks1.head()
# Out:
#              beer  spirit  wine  liters continent
# Afghanistan     0       0     0     0.0        AS
# Albania        89     132    54     4.9        EU
# Algeria        25       0    14     0.7        AF
# Andorra       245     138   312    12.4        EU
# Angola        217      57    45     5.9        AF

# %%
drinks1['beer'][:10].plot(kind='bar')

# %%
drinks1['beer'][:10]
# Out:
# Afghanistan            0
# Albania               89
# Algeria               25
# Andorra              245
# Angola               217
# Antigua & Barbuda    102
# Argentina            193
# Armenia               21
# Australia            261
# Austria              279
# Name: beer, dtype: int64

# %%
drinks[['beer','wine']].plot()

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/ufo.csv'
ufo = pd.read_csv(url)
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
ufo.Year.value_counts().sort_index(ascending=False).head()
# Out:
# 2014    5382
# 2013    7003
# 2012    7263
# 2011    5089
# 2010    4154
# Name: Year, dtype: int64

# %%
ufo.Year.value_counts().sort_index().plot()

# %%
drinks.continent.value_counts().plot()

# %%
drinks.beer.plot(kind='hist', bins = 100)

# %%
drinks.beer.plot(kind='hist', bins=20)
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.title('Histogram of Beer Servings')
plt.savefig('histo.png')

# %%
drinks.beer.plot(kind='density',xlim=(0,500))

# %%
drinks.hist(column='beer',by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9DFD42BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1839CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E185A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1873780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1890CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E18B22B0>]],
#       dtype=object)

# %%
drinks.hist(column='beer',by='continent',sharex=True,sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1B959E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1BC9828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1BEAB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1C10DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1C3D0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E1C633C8>]],
#       dtype=object)

# %%
drinks[['beer','wine']].sort_values('beer')
# Out:
#      beer  wine
# 0       0     0
# 40      0    74
# 79      0     0
# 90      0     0
# 97      0     0
# 103     0     0
# 106     0     0
# 111     0     0
# 128     0     0
# 147     0     0
# 13      0     0
# 149     0     0
# 107     0     0
# 158     0     0
# 46      0     0
# 137     1     7
# 38      1     1
# 171     1     4
# 73      1     1
# 168     2     0
# 123     3     1
# 119     5     0
# 116     5     0
# 167     5    16
# 104     5     1
# 78      5     0
# 53      6     1
# 190     6     0
# 86      6     1
# 178     6     9
# ..    ...   ...
# 76    233    78
# 75    234   185
# 99    236   271
# 109   238     5
# 32    240   100
# 3     245   312
# 23    245    16
# 141   247    73
# 184   249    84
# 120   251   190
# 8     261   212
# 60    263    97
# 17    263     8
# 156   270   276
# 9     279   191
# 93    281    62
# 151   283   127
# 160   284   112
# 130   285    18
# 16    295   212
# 140   297   167
# 129   306    23
# 81    313   165
# 188   333     3
# 98    343    56
# 135   343    56
# 65    346   175
# 62    347    59
# 45    361   134
# 117   376     1
#
# [193 rows x 2 columns]

# %%
drinks.plot(kind='scatter',x='beer',y='wine')

# %%
drinks.plot(kind='scatter',x='beer',y='wine',alpha=0.2)

# %%
drinks.plot(kind='scatter',x='beer',y='wine',c='spirit',colormap='Blues')

# %%
pd.plotting.scatter_matrix(drinks)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E2158898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3E7A588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E277C828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3EB5DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E214E358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E27C58D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3DDAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E26A8438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E26A8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3BCDEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3BED470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3C0A9E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3C24F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3C45518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3C63A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E3C8F048>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(drinks[['beer','spirit','wine']],figsize=(5,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E4185F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E5752908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E5773E80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E579F438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E5729B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E418DAC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E57EB160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E580E400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E580E438>]],
#       dtype=object)

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().plot(kind='barh')

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
drinks.groupby('continent').mean().T
# Out:
# continent         AF         AS          EU          NA        OC          SA
# beer       61.471698  37.045455  193.777778  145.434783  89.68750  175.083333
# spirit     16.339623  60.840909  132.555556  165.739130  58.43750  114.750000
# wine       16.264151   9.068182  142.222222   24.521739  35.62500   62.416667
# liters      3.007547   2.170455    8.617778    5.995652   3.38125    6.308333

# %%
drinks.groupby('continent').mean().T.plot(kind='bar')

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %%
drinks.groupby('continent').mean().plot(kind='bar',stacked=True)

# %%
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar',stacked=True)

# %%
drinks.spirit.head()
# Out:
# 0      0
# 1    132
# 2      0
# 3    138
# 4     57
# Name: spirit, dtype: int64

# %%
drink_country = drinks[['beer', 'wine']].sum(axis=1)
drink_country.index=drinks.country
drink_country10 = drink_country.sort_values(ascending=False)[:10]
drink_country10.plot(kind='bar')

# %%
drinks.sum(axis=1).plot(kind='bar')

# %%
 drinks[['beer','spirit','wine','liters']].sum(axis=0).plot(kind='bar')

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks.plot(kind='box')

# %%
drinks.spirit.plot(kind='box')

# %%
drinks.boxplot(column='beer', by='continent')

# %%
drinks.groupby('continent').mean().T
# Out:
# continent         AF         AS          EU          NA        OC          SA
# beer       61.471698  37.045455  193.777778  145.434783  89.68750  175.083333
# spirit     16.339623  60.840909  132.555556  165.739130  58.43750  114.750000
# wine       16.264151   9.068182  142.222222   24.521739  35.62500   62.416667
# liters      3.007547   2.170455    8.617778    5.995652   3.38125    6.308333

# %%
drinks.groupby('continent').mean().T.plot(kind='box')

# %%
drinks.boxplot(by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E783A278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E788E6D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E78B86A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9E78DF668>]],
#       dtype=object)
